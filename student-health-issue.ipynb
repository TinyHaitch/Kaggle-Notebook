# %%
import os
import warnings
import time
import warnings
from copy import deepcopy
from importlib.metadata import version
from itertools import combinations

# Data handling and visualization modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
import seaborn as sns


warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.3f}'.format)
pd.set_option('future.no_silent_downcasting', True)

# %%
test_data = pd.read_csv(r"/kaggle/input/competitions/playground-series-s6e7/test.csv")
train_data = pd.read_csv(r"/kaggle/input/competitions/playground-series-s6e7/train.csv")

test_data
# Out:
#             id  sleep_duration  heart_rate    bmi  calorie_expenditure  \
# 0       690088           5.350      64.900 23.480             2745.000
# 1       690089             NaN      83.100 22.420             1773.000
# 2       690090           6.680      59.700 24.140             3040.000
# 3       690091           7.130      78.500 26.260             2494.000
# 4       690092           5.490      77.700 23.290             1828.000
# ...        ...             ...         ...    ...                  ...
# 295748  985836           7.130      77.500 22.200             2221.000
# 295749  985837           6.250      69.500 20.930             2242.000
# 295750  985838             NaN      77.000 23.620             2111.000
# 295751  985839           7.250      66.300 21.470             2009.000
# 295752  985840           4.610      85.100 23.790             2456.000
#
#         step_count  exercise_duration  water_intake diet_type stress_level  \
# 0        14167.000             59.500         1.860       veg         high
# 1         6801.000             24.500         2.400  balanced         high
# 2        13250.000             48.500         2.760  balanced       medium
# 3         6331.000             56.900         2.340       veg          low
# 4        13894.000             39.400         2.450       veg         high
# ...            ...                ...           ...       ...          ...
# 295748   13981.000             65.600         2.170  balanced          low
# 295749    2370.000             23.600         1.980  balanced          NaN
# 295750    7647.000             25.100         2.180       veg         high
# 295751    4672.000             25.100         2.020       veg         high
# 295752   14195.000             50.500         2.300   non-veg         high
#
#        sleep_quality physical_activity_level smoking_alcohol  gender
# 0               poor                  active      occasional    male
# 1               poor               sedentary             yes   other
# 2               poor                  active              no     NaN
# 3               good                moderate             yes   other
# 4            average                  active      occasional   other
# ...              ...                     ...             ...     ...
# 295748       average                  active      occasional   other
# 295749       average                moderate             yes  female
# 295750       average               sedentary              no   other
# 295751          poor                moderate              no  female
# 295752       average                  active      occasional   other
#
# [295753 rows x 14 columns]

# %%
test_data.shape
# Out:
# (295753, 14)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295753 entries, 0 to 295752
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       295753 non-null  int64
#  1   sleep_duration           263182 non-null  float64
#  2   heart_rate               292396 non-null  float64
#  3   bmi                      289797 non-null  float64
#  4   calorie_expenditure      273101 non-null  float64
#  5   step_count               289789 non-null  float64
#  6   exercise_duration        292795 non-null  float64
#  7   water_intake             277120 non-null  float64
#  8   diet_type                292795 non-null  object
#  9   stress_level             260263 non-null  object
#  10  sleep_quality            270754 non-null  object
#  11  physical_activity_level  280058 non-null  object
#  12  smoking_alcohol          283504 non-null  object
#  13  gender                   286593 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 31.6+ MB

# %%
(test_data.isnull().sum() / len(test_data)) * 100
# Out:
# id                         0.000
# sleep_duration            11.013
# heart_rate                 1.135
# bmi                        2.014
# calorie_expenditure        7.659
# step_count                 2.017
# exercise_duration          1.000
# water_intake               6.300
# diet_type                  1.000
# stress_level              12.000
# sleep_quality              8.453
# physical_activity_level    5.307
# smoking_alcohol            4.142
# gender                     3.097
# dtype: float64

# %%
test_data['stress_level'].value_counts() / len(test_data['stress_level']) * 100
# Out:
# stress_level
# medium   38.061
# high     25.639
# low      24.300
# Name: count, dtype: float64

# %%
import plotly.express as px

# Interactive bar chart of categorical column
fig = px.bar(
    test_data['stress_level'].value_counts().reset_index(),
    x='stress_level',
    y='count',
    title='Stress Level Distribution',
    color='stress_level',
    text='count'          # shows count on each bar
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7e6ae1d-8eb8-4fc6-8102-645820d2fb61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7e6ae1d-8eb8-4fc6-8102-645820d2fb61")) {                    Plotly.newPlot(                        "e7e6ae1d-8eb8-4fc6-8102-645820d2fb61",                        [{"alignmentgroup":"True","hovertemplate":"stress_level=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"medium","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"medium","offsetgroup":"medium","orientation":"v","showlegend":true,"text":[112568.0],"textposition":"auto","x":["medium"],"xaxis":"x","y":[112568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"stress_level=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"high","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"high","offsetgroup":"high","orientation":"v","showlegend":true,"text":[75828.0],"textposition":"auto","x":["high"],"xaxis":"x","y":[75828],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"stress_level=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"low","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"low","offsetgroup":"low","orientation":"v","showlegend":true,"text":[71867.0],"textposition":"auto","x":["low"],"xaxis":"x","y":[71867],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...
